# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import sklearn
import random
from unicodedata import normalize
from keras.layers import Dense
from keras import Input
from keras_preprocessing.sequence import pad_sequences 
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 오디오 데이터
DATA_DIR_TRAIN = '/content/drive/My Drive/특화_음성/real_check/train/'
DATA_DIR_TEST = '/content/drive/My Drive/특화_음성/real_check/test/'

# %%
train_X = []
train_spectrograms = []
train_mel_spectograms = []
train_mfccs = []
train_y = []

test_X = []
test_spectrograms = []
test_mel_spectograms = []
test_mfccs = []
test_y = []

pad1d = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i-a.shape[0])))
pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))

# STFT 한 것, CNN 분석하기 위해 Spectogram으로 만든 것, MF한 것, mel0spectogram 한 것

# %%
test_dataset = []
train_dataset = []

frame_length = 0.025
frame_stride = 0.01
sr=16000

input_nfft = int(round(sr*frame_length))
input_stride = int(round(sr*frame_stride))
print(input_nfft,input_stride)
# Out:
# 400 160

# %%
#train data set
for filename in os.listdir(DATA_DIR_TRAIN):
  filename = normalize('NFC', filename) # 'ㅇㅡㅁ.wav' -> '음.wav'
  try:
      
    audio, sr = librosa.load(DATA_DIR_TRAIN + filename, sr=16000)
  
    mfcc = librosa.feature.mfcc(audio, sr=16000, n_mfcc=100, n_fft=input_nfft, hop_length=input_stride)
    mfcc = sklearn.preprocessing.scale(mfcc, axis=1)
    padded_mfcc = pad2d(mfcc, 100)

    # 응/아니오 구분하여 dataset에 추가
    if filename[0] == '응':
      train_dataset.append((padded_mfcc, 1))
    else:
      train_dataset.append((padded_mfcc, 0))
  except Exception as e:
    print(filename, e)
    raise
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# ...
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "

# %%
# test data set
for filename in os.listdir(DATA_DIR_TEST):
  filename = normalize('NFC', filename)
  try:
      
    audio, sr = librosa.load(DATA_DIR_TEST + filename, sr=16000)

    input_nfft = int(round(sr*frame_length))
    input_stride = int(round(sr*frame_stride))
  
    mfcc = librosa.feature.mfcc(audio, sr=16000, n_mfcc=100, n_fft=input_nfft, hop_length=input_stride)
    mfcc = sklearn.preprocessing.scale(mfcc, axis=1)
    padded_mfcc = pad2d(mfcc, 100)

    # 응/아니 구분하여 dataset에 추가
    if filename[0] == '응':
      test_dataset.append((padded_mfcc, 1))
    else:
      test_dataset.append((padded_mfcc, 0))
  except Exception as e:
    print(filename, e)
    raise
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "

# %%
# 데이터셋을 셔플
random.shuffle(test_dataset)
random.shuffle(train_dataset)

train_mfccs = [a for (a,b) in train_dataset]
train_y = [b for (a,b) in train_dataset]

test_mfccs = [a for (a,b) in test_dataset]
test_y = [b for (a,b) in test_dataset]

train_mfccs = np.array(train_mfccs)
train_y = tf.keras.utils.to_categorical(np.array(train_y))

test_mfccs = np.array(test_mfccs)
test_y = tf.keras.utils.to_categorical(np.array(test_y))

print('train_mfccs:', train_mfccs.shape)
print('train_y:', train_y.shape)
print('test_mfccs:', test_mfccs.shape)
print('test_y:', test_y.shape)
# Out:
# train_mfccs: (270, 100, 100)
# train_y: (270, 2)
# test_mfccs: (30, 100, 100)
# test_y: (30, 2)

# %%
# MFCC feature로 학습
train_X_ex = np.expand_dims(train_mfccs, -1)
test_X_ex = np.expand_dims(test_mfccs, -1)
print('train X shape:', train_X_ex.shape)
print('test X shape:', test_X_ex.shape)
# Out:
# train X shape: (270, 100, 100, 1)
# test X shape: (30, 100, 100, 1)

# %%
ip = Input(shape=train_X_ex[0].shape)

m = tf.keras.layers.Conv2D(32, kernel_size=(4,4), activation='relu')(ip)
#m = tf.keras.layers.BatchNormalization()(m)
m = tf.keras.layers.MaxPooling2D(pool_size=(4,4))(m)

m =tf.keras.layers.Conv2D(32*2, kernel_size=(4,4), activation='relu')(ip)
#m = tf.keras.layers.BatchNormalization()(m)
m = tf.keras.layers.MaxPooling2D(pool_size=(4,4))(m)

m = tf.keras.layers.Conv2D(32*3, kernel_size=(4,4), activation='relu')(ip)
#m = tf.keras.layers.BatchNormalization()(m)
m = tf.keras.layers.MaxPooling2D(pool_size=(4,4))(m)

m = tf.keras.layers.Flatten()(m)

m = Dense(32)(m)
#m = tf.keras.layers.BatchNormalization()(m)
m = tf.keras.layers.Activation("relu")(m)

op = Dense(2, activation='softmax')(m)

model = tf.keras.Model(ip, op)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d_2 (Conv2D)           (None, 97, 97, 96)        1632
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 96)       0
#  2D)
#
#  flatten (Flatten)           (None, 55296)             0
#
#  dense (Dense)               (None, 32)                1769504
#
#  activation (Activation)     (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,771,202
# Trainable params: 1,771,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X_ex,
                    train_y,
                    epochs=100,
                    batch_size=32,
                    verbose=1,
                    validation_data=(test_X_ex, test_y))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 4s 332ms/step - loss: 5.1250 - accuracy: 0.5074 - val_loss: 1.0555 - val_accuracy: 0.5000
# Epoch 2/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.5169 - accuracy: 0.5111 - val_loss: 1.0629 - val_accuracy: 0.5000
# Epoch 3/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.8595 - accuracy: 0.5296 - val_loss: 0.7477 - val_accuracy: 0.4667
# Epoch 4/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.6662 - accuracy: 0.6222 - val_loss: 0.9815 - val_accuracy: 0.5000
# Epoch 5/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.6303 - accuracy: 0.6519 - val_loss: 0.6561 - val_accuracy: 0.5667
# Epoch 6/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.4427 - accuracy: 0.8778 - val_loss: 0.6415 - val_accuracy: 0.6333
# Epoch 7/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.4284 - accuracy: 0.8296 - val_loss: 0.7019 - val_accuracy: 0.5000
# Epoch 8/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.4624 - accuracy: 0.7148 - val_loss: 0.6526 - val_accuracy: 0.5000
# Epoch 9/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.3464 - accuracy: 0.9037 - val_loss: 0.7771 - val_accuracy: 0.5000
# Epoch 10/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.3003 - accuracy: 0.9370 - val_loss: 0.6307 - val_accuracy: 0.6000
# Epoch 11/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.2243 - accuracy: 0.9704 - val_loss: 0.5973 - val_accuracy: 0.6667
# Epoch 12/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.2124 - accuracy: 0.9667 - val_loss: 0.7202 - val_accuracy: 0.5667
# Epoch 13/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.1597 - accuracy: 0.9889 - val_loss: 0.7332 - val_accuracy: 0.5333
# Epoch 14/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.1222 - accuracy: 0.9963 - val_loss: 0.6465 - val_accuracy: 0.5333
# Epoch 15/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.1020 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.7333
# Epoch 16/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 0.5714 - val_accuracy: 0.6333
# Epoch 17/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.7856 - val_accuracy: 0.5000
# Epoch 18/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.7350 - val_accuracy: 0.5333
# Epoch 19/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.5885 - val_accuracy: 0.6333
# Epoch 20/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.7000
# Epoch 21/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.6667
# Epoch 22/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.5421 - val_accuracy: 0.6667
# Epoch 23/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.5401 - val_accuracy: 0.7000
# Epoch 24/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.5610 - val_accuracy: 0.6333
# Epoch 25/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5845 - val_accuracy: 0.6333
# Epoch 26/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.6290 - val_accuracy: 0.6000
# Epoch 27/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.5787 - val_accuracy: 0.6667
# Epoch 28/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.5410 - val_accuracy: 0.7000
# Epoch 29/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.5413 - val_accuracy: 0.7000
# Epoch 30/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.5743 - val_accuracy: 0.6667
# Epoch 31/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5938 - val_accuracy: 0.6667
# Epoch 32/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.6667
# Epoch 33/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.6000
# Epoch 34/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.6667
# Epoch 35/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.6009 - val_accuracy: 0.6667
# Epoch 36/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.6608 - val_accuracy: 0.6000
# Epoch 37/100
# 9/9 [==============================] - 3s 312ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.7000
# Epoch 38/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5702 - val_accuracy: 0.7000
# Epoch 39/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.6426 - val_accuracy: 0.6000
# Epoch 40/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.6058 - val_accuracy: 0.6667
# Epoch 41/100
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5787 - val_accuracy: 0.7000
# Epoch 42/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6527 - val_accuracy: 0.6000
# Epoch 43/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5895 - val_accuracy: 0.7000
# Epoch 44/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.5973 - val_accuracy: 0.7000
# Epoch 45/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.6583 - val_accuracy: 0.6000
# Epoch 46/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.6667
# Epoch 47/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.6000
# Epoch 48/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6508 - val_accuracy: 0.6000
# Epoch 49/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5742 - val_accuracy: 0.7000
# Epoch 50/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6475 - val_accuracy: 0.6000
# Epoch 51/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6228 - val_accuracy: 0.6667
# Epoch 52/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6101 - val_accuracy: 0.7000
# Epoch 53/100
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6194 - val_accuracy: 0.7000
# Epoch 54/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.7000
# Epoch 55/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.7000
# Epoch 56/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6223 - val_accuracy: 0.7000
# Epoch 57/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6220 - val_accuracy: 0.7000
# Epoch 58/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6051 - val_accuracy: 0.7000
# Epoch 59/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6394 - val_accuracy: 0.6333
# Epoch 60/100
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.6667
# Epoch 61/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6254 - val_accuracy: 0.7000
# Epoch 62/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.7000
# Epoch 63/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6339 - val_accuracy: 0.6667
# Epoch 64/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6333 - val_accuracy: 0.6667
# Epoch 65/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6290 - val_accuracy: 0.6667
# Epoch 66/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6262 - val_accuracy: 0.7000
# Epoch 67/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6451 - val_accuracy: 0.6333
# Epoch 68/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6173 - val_accuracy: 0.7000
# Epoch 69/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6368 - val_accuracy: 0.7000
# Epoch 70/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6221 - val_accuracy: 0.7000
# Epoch 71/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6415 - val_accuracy: 0.6667
# Epoch 72/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6506 - val_accuracy: 0.6333
# Epoch 73/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6276 - val_accuracy: 0.7000
# Epoch 74/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6469 - val_accuracy: 0.6667
# Epoch 75/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.7000
# Epoch 76/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6505 - val_accuracy: 0.6667
# Epoch 77/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6432 - val_accuracy: 0.6667
# Epoch 78/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6309 - val_accuracy: 0.7000
# Epoch 79/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6474 - val_accuracy: 0.6667
# Epoch 80/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6256 - val_accuracy: 0.7000
# Epoch 81/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6486 - val_accuracy: 0.6667
# Epoch 82/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6324 - val_accuracy: 0.7000
# Epoch 83/100
# 9/9 [==============================] - 3s 309ms/step - loss: 9.7803e-04 - accuracy: 1.0000 - val_loss: 0.6430 - val_accuracy: 0.7000
# Epoch 84/100
# 9/9 [==============================] - 3s 304ms/step - loss: 9.5813e-04 - accuracy: 1.0000 - val_loss: 0.6432 - val_accuracy: 0.7000
# Epoch 85/100
# 9/9 [==============================] - 3s 305ms/step - loss: 9.2738e-04 - accuracy: 1.0000 - val_loss: 0.6492 - val_accuracy: 0.6667
# Epoch 86/100
# 9/9 [==============================] - 3s 309ms/step - loss: 9.1128e-04 - accuracy: 1.0000 - val_loss: 0.6417 - val_accuracy: 0.7000
# Epoch 87/100
# 9/9 [==============================] - 3s 311ms/step - loss: 8.8618e-04 - accuracy: 1.0000 - val_loss: 0.6499 - val_accuracy: 0.6667
# Epoch 88/100
# 9/9 [==============================] - 3s 307ms/step - loss: 8.5980e-04 - accuracy: 1.0000 - val_loss: 0.6372 - val_accuracy: 0.7000
# Epoch 89/100
# 9/9 [==============================] - 3s 303ms/step - loss: 8.4638e-04 - accuracy: 1.0000 - val_loss: 0.6477 - val_accuracy: 0.7000
# Epoch 90/100
# 9/9 [==============================] - 3s 309ms/step - loss: 8.1949e-04 - accuracy: 1.0000 - val_loss: 0.6367 - val_accuracy: 0.7000
# Epoch 91/100
# 9/9 [==============================] - 3s 303ms/step - loss: 8.1435e-04 - accuracy: 1.0000 - val_loss: 0.6529 - val_accuracy: 0.6667
# Epoch 92/100
# 9/9 [==============================] - 3s 312ms/step - loss: 7.7998e-04 - accuracy: 1.0000 - val_loss: 0.6536 - val_accuracy: 0.6667
# Epoch 93/100
# 9/9 [==============================] - 3s 304ms/step - loss: 7.6215e-04 - accuracy: 1.0000 - val_loss: 0.6476 - val_accuracy: 0.7000
# Epoch 94/100
# 9/9 [==============================] - 3s 310ms/step - loss: 7.5134e-04 - accuracy: 1.0000 - val_loss: 0.6447 - val_accuracy: 0.7000
# Epoch 95/100
# 9/9 [==============================] - 3s 304ms/step - loss: 7.2870e-04 - accuracy: 1.0000 - val_loss: 0.6530 - val_accuracy: 0.7000
# Epoch 96/100
# 9/9 [==============================] - 3s 306ms/step - loss: 7.1100e-04 - accuracy: 1.0000 - val_loss: 0.6436 - val_accuracy: 0.7000
# Epoch 97/100
# 9/9 [==============================] - 3s 303ms/step - loss: 6.9804e-04 - accuracy: 1.0000 - val_loss: 0.6535 - val_accuracy: 0.7000
# Epoch 98/100
# 9/9 [==============================] - 3s 311ms/step - loss: 6.8126e-04 - accuracy: 1.0000 - val_loss: 0.6458 - val_accuracy: 0.7000
# Epoch 99/100
# 9/9 [==============================] - 3s 308ms/step - loss: 6.6724e-04 - accuracy: 1.0000 - val_loss: 0.6508 - val_accuracy: 0.7000
# Epoch 100/100
# 9/9 [==============================] - 3s 307ms/step - loss: 6.5249e-04 - accuracy: 1.0000 - val_loss: 0.6505 - val_accuracy: 0.7000

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
# 샘플 오디오 데이터
DATA_DIR = '/content/drive/My Drive/특화_음성/tutorial/'

wav, sr = librosa.load(DATA_DIR + 'sample_5(안녕).wav', sr=None)
print('sr:', sr)
print('wav shape:', wav.shape)
print('length:', wav.shape[0]/float(sr), 'secs')
# Out:
# sr: 44100
# wav shape: (90317,)
# length: 2.0480045351473923 secs

# %%
mfcc = librosa.feature.mfcc(wav, n_mfcc=100)
padded_mfcc = pad2d(mfcc, 300)
padded_mfcc = np.expand_dims(padded_mfcc, 0)

result = model.predict(padded_mfcc)
print(result)
if result[0][0] <= result[0][1]: # 인사
  print('인사') 
else:
  print('인사 아님')
# Out:
# [[1. 0.]]
# 인사 아님

# %%
model.save('/content/drive/My Drive/졸프/0726Data/filler_determine_model_by_train2_1205.h5')
